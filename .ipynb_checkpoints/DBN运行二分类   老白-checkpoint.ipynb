# %%
import numpy as np

np.random.seed(1337)  # for reproducibility
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score,confusion_matrix,f1_score,precision_score
from sklearn.metrics import cohen_kappa_score,hamming_loss,precision_recall_curve
from sklearn.metrics import roc_curve,auc
#分类报告
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from dbn.tensorflow import SupervisedDBNClassification
import tensorflow._api.v2.compat.v1 as tf
#import tensorflow.compat.v1 as tf ###
#tf.disable_v2_behavior()
import  pandas as pd
#import eli5
#from eli5.sklearn import PermutationImportance
#import shap
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MinMaxScaler

print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-326e01553730> in <module>
#      10 from sklearn.metrics import classification_report
#      11 from matplotlib import pyplot as plt
# ---> 12 from dbn.tensorflow import SupervisedDBNClassification
#      13 import tensorflow._api.v2.compat.v1 as tf
#      14 #import tensorflow.compat.v1 as tf ###
#
# D:\python\TensorflowFiles\DBN\dbn\tensorflow\__init__.py in <module>
# ----> 1 from .models import BinaryRBM, UnsupervisedDBN, SupervisedDBNRegression, SupervisedDBNClassification
#
# D:\python\TensorflowFiles\DBN\dbn\tensorflow\models.py in <module>
#      17
#      18
# ---> 19 sess = tf.Session()
#      20 atexit.register(close_session)
#      21
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %%
# Loading dataset
# digits = load_digits()
# X, Y = digits.data, digits.target
#data = pd.read_csv(r'Ctrain.csv',sep=',')
data = pd.read_csv(r'train2.csv',sep=',')
#data_= pd.read_csv(r'test4.csv',sep=',')
data_.dropna(inplace=True)
#导入数据
label_index = 7
dim  = 7
# data[label_index] = data[label_index].map({1:1, 2:-1})
data = data.sample(frac=1.0)
data = data.reset_index()
x = data.drop(['landslide'],axis=1)
print(x.shape)
x = x.drop(['index'],axis=1)
x = np.array(x)
print(x.shape)
std=MinMaxScaler((0,1))
x=std.fit_transform(x)
y = data['landslide']
y = pd.to_numeric( y, errors='coerce').fillna('0').astype('int32')
# Data scaling
# X = (X / 16).astype(np.float32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f5f20e360f84> in <module>
#       3 # X, Y = digits.data, digits.target
#       4 #data = pd.read_csv(r'Ctrain.csv',sep=',')
# ----> 5 data = pd.read_csv(r'train2.csv',sep=',')
#       6 #data_= pd.read_csv(r'test4.csv',sep=',')
#       7 data_.dropna(inplace=True)
#
# NameError: name 'pd' is not defined

# %%
#训练
data_ = data_.sample(frac=1.0)
data_ = data_.reset_index()
x_ = data_.drop(['landslide','pre1'],axis=1)
x_ = x_.drop(['index'],axis=1)
x_ = np.array(x_)
res=x_
print(x_.shape)
std=MinMaxScaler((0,1))
x_=std.fit_transform(x_)
y_ = data_['landslide']
y_ = pd.to_numeric( y_, errors='coerce').fillna('0').astype('int32')
# Out:
# (9797311, 9)

# %%
# Splitting data
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=1)#random_state=0
X_train[:,2:]
# Training
classifier = SupervisedDBNClassification(hidden_layers_structure=[100, 100],
                                         learning_rate_rbm=0.07, 
                                         learning_rate=0.15,
                                         n_epochs_rbm=16,
                                         n_iter_backprop=500,
                                         batch_size=20,
                                         activation_function='relu',
                                         dropout_p=0)
classifier.fit(X_train[:,2:], Y_train)
# Out:
# [START] Pre-training step:
# >> Epoch 1 finished 	RBM Reconstruction error 0.301368
# >> Epoch 2 finished 	RBM Reconstruction error 0.219151
# >> Epoch 3 finished 	RBM Reconstruction error 0.164604
# >> Epoch 4 finished 	RBM Reconstruction error 0.159476
# >> Epoch 5 finished 	RBM Reconstruction error 0.149685
# >> Epoch 6 finished 	RBM Reconstruction error 0.126060
# >> Epoch 7 finished 	RBM Reconstruction error 0.115962
# >> Epoch 8 finished 	RBM Reconstruction error 0.120337
# >> Epoch 9 finished 	RBM Reconstruction error 0.115041
# >> Epoch 10 finished 	RBM Reconstruction error 0.118898
# >> Epoch 11 finished 	RBM Reconstruction error 0.125365
# >> Epoch 12 finished 	RBM Reconstruction error 0.109913
# >> Epoch 13 finished 	RBM Reconstruction error 0.119237
# >> Epoch 14 finished 	RBM Reconstruction error 0.105596
# >> Epoch 15 finished 	RBM Reconstruction error 0.119272
# >> Epoch 16 finished 	RBM Reconstruction error 0.120871
# >> Epoch 1 finished 	RBM Reconstruction error 0.349984
# >> Epoch 2 finished 	RBM Reconstruction error 0.243302
# >> Epoch 3 finished 	RBM Reconstruction error 0.249232
# >> Epoch 4 finished 	RBM Reconstruction error 0.323146
# >> Epoch 5 finished 	RBM Reconstruction error 0.333173
# >> Epoch 6 finished 	RBM Reconstruction error 0.204110
# >> Epoch 7 finished 	RBM Reconstruction error 0.218970
# >> Epoch 8 finished 	RBM Reconstruction error 0.332887
# >> Epoch 9 finished 	RBM Reconstruction error 0.155367
# >> Epoch 10 finished 	RBM Reconstruction error 0.121216
# >> Epoch 11 finished 	RBM Reconstruction error 0.205107
# >> Epoch 12 finished 	RBM Reconstruction error 0.240920
# >> Epoch 13 finished 	RBM Reconstruction error 0.213526
# >> Epoch 14 finished 	RBM Reconstruction error 0.288171
# >> Epoch 15 finished 	RBM Reconstruction error 0.218277
# >> Epoch 16 finished 	RBM Reconstruction error 0.251385
# [END] Pre-training step
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.670093
# >> Epoch 1 finished 	ANN training loss 0.624066
# >> Epoch 2 finished 	ANN training loss 0.608577
# >> Epoch 3 finished 	ANN training loss 0.585740
# >> Epoch 4 finished 	ANN training loss 0.582186
# >> Epoch 5 finished 	ANN training loss 0.577565
# >> Epoch 6 finished 	ANN training loss 0.594267
# >> Epoch 7 finished 	ANN training loss 0.562231
# >> Epoch 8 finished 	ANN training loss 0.560696
# >> Epoch 9 finished 	ANN training loss 0.543080
# >> Epoch 10 finished 	ANN training loss 0.534148
# >> Epoch 11 finished 	ANN training loss 0.531344
# >> Epoch 12 finished 	ANN training loss 0.537673
# >> Epoch 13 finished 	ANN training loss 0.521996
# >> Epoch 14 finished 	ANN training loss 0.577294
# >> Epoch 15 finished 	ANN training loss 0.513239
# >> Epoch 16 finished 	ANN training loss 0.543638
# >> Epoch 17 finished 	ANN training loss 0.505668
# >> Epoch 18 finished 	ANN training loss 0.513640
# >> Epoch 19 finished 	ANN training loss 0.504629
# >> Epoch 20 finished 	ANN training loss 0.494996
# >> Epoch 21 finished 	ANN training loss 0.521192
# >> Epoch 22 finished 	ANN training loss 0.496834
# >> Epoch 23 finished 	ANN training loss 0.503526
# >> Epoch 24 finished 	ANN training loss 0.504798
# >> Epoch 25 finished 	ANN training loss 0.492037
# >> Epoch 26 finished 	ANN training loss 0.505472
# >> Epoch 27 finished 	ANN training loss 0.488637
# >> Epoch 28 finished 	ANN training loss 0.486684
# >> Epoch 29 finished 	ANN training loss 0.517839
# >> Epoch 30 finished 	ANN training loss 0.495724
# >> Epoch 31 finished 	ANN training loss 0.483663
# >> Epoch 32 finished 	ANN training loss 0.482777
# >> Epoch 33 finished 	ANN training loss 0.486293
# >> Epoch 34 finished 	ANN training loss 0.479304
# >> Epoch 35 finished 	ANN training loss 0.650271
# >> Epoch 36 finished 	ANN training loss 0.492595
# >> Epoch 37 finished 	ANN training loss 0.471227
# >> Epoch 38 finished 	ANN training loss 0.479846
# >> Epoch 39 finished 	ANN training loss 0.500440
# >> Epoch 40 finished 	ANN training loss 0.509174
# >> Epoch 41 finished 	ANN training loss 0.459416
# >> Epoch 42 finished 	ANN training loss 0.479760
# >> Epoch 43 finished 	ANN training loss 0.473016
# >> Epoch 44 finished 	ANN training loss 0.465907
# >> Epoch 45 finished 	ANN training loss 0.488161
# >> Epoch 46 finished 	ANN training loss 0.480916
# >> Epoch 47 finished 	ANN training loss 0.461146
# >> Epoch 48 finished 	ANN training loss 0.457218
# >> Epoch 49 finished 	ANN training loss 0.460433
# >> Epoch 50 finished 	ANN training loss 0.456503
# >> Epoch 51 finished 	ANN training loss 0.462054
# >> Epoch 52 finished 	ANN training loss 0.479917
# >> Epoch 53 finished 	ANN training loss 0.457631
# >> Epoch 54 finished 	ANN training loss 0.477113
# >> Epoch 55 finished 	ANN training loss 0.447277
# >> Epoch 56 finished 	ANN training loss 0.448408
# >> Epoch 57 finished 	ANN training loss 0.449670
# >> Epoch 58 finished 	ANN training loss 0.448828
# >> Epoch 59 finished 	ANN training loss 0.466479
# >> Epoch 60 finished 	ANN training loss 0.446390
# >> Epoch 61 finished 	ANN training loss 0.461469
# >> Epoch 62 finished 	ANN training loss 0.459216
# >> Epoch 63 finished 	ANN training loss 0.446295
# >> Epoch 64 finished 	ANN training loss 0.445816
# >> Epoch 65 finished 	ANN training loss 0.437626
# >> Epoch 66 finished 	ANN training loss 0.466779
# >> Epoch 67 finished 	ANN training loss 0.440674
# >> Epoch 68 finished 	ANN training loss 0.446747
# >> Epoch 69 finished 	ANN training loss 0.449692
# >> Epoch 70 finished 	ANN training loss 0.432521
# >> Epoch 71 finished 	ANN training loss 0.448596
# >> Epoch 72 finished 	ANN training loss 0.432499
# >> Epoch 73 finished 	ANN training loss 0.434838
# >> Epoch 74 finished 	ANN training loss 0.457327
# >> Epoch 75 finished 	ANN training loss 0.432876
# >> Epoch 76 finished 	ANN training loss 0.431971
# >> Epoch 77 finished 	ANN training loss 0.444212
# >> Epoch 78 finished 	ANN training loss 0.427322
# >> Epoch 79 finished 	ANN training loss 0.439218
# >> Epoch 80 finished 	ANN training loss 0.431721
# >> Epoch 81 finished 	ANN training loss 0.425854
# >> Epoch 82 finished 	ANN training loss 0.426826
# >> Epoch 83 finished 	ANN training loss 0.427234
# >> Epoch 84 finished 	ANN training loss 0.419130
# >> Epoch 85 finished 	ANN training loss 0.429568
# >> Epoch 86 finished 	ANN training loss 0.449747
# >> Epoch 87 finished 	ANN training loss 0.430837
# >> Epoch 88 finished 	ANN training loss 0.437448
# >> Epoch 89 finished 	ANN training loss 0.418789
# >> Epoch 90 finished 	ANN training loss 0.418058
# >> Epoch 91 finished 	ANN training loss 0.418403
# >> Epoch 92 finished 	ANN training loss 0.422419
# >> Epoch 93 finished 	ANN training loss 0.424964
# >> Epoch 94 finished 	ANN training loss 0.423308
# >> Epoch 95 finished 	ANN training loss 0.421143
# >> Epoch 96 finished 	ANN training loss 0.431575
# >> Epoch 97 finished 	ANN training loss 0.415606
# >> Epoch 98 finished 	ANN training loss 0.416855
# >> Epoch 99 finished 	ANN training loss 0.416824
# >> Epoch 100 finished 	ANN training loss 0.421336
# >> Epoch 101 finished 	ANN training loss 0.414190
# >> Epoch 102 finished 	ANN training loss 0.434154
# >> Epoch 103 finished 	ANN training loss 0.450334
# >> Epoch 104 finished 	ANN training loss 0.413813
# >> Epoch 105 finished 	ANN training loss 0.411479
# >> Epoch 106 finished 	ANN training loss 0.419615
# >> Epoch 107 finished 	ANN training loss 0.401475
# >> Epoch 108 finished 	ANN training loss 0.414136
# >> Epoch 109 finished 	ANN training loss 0.423969
# >> Epoch 110 finished 	ANN training loss 0.423026
# >> Epoch 111 finished 	ANN training loss 0.406626
# >> Epoch 112 finished 	ANN training loss 0.412756
# >> Epoch 113 finished 	ANN training loss 0.409052
# >> Epoch 114 finished 	ANN training loss 0.419946
# >> Epoch 115 finished 	ANN training loss 0.408126
# >> Epoch 116 finished 	ANN training loss 0.394590
# >> Epoch 117 finished 	ANN training loss 0.406046
# >> Epoch 118 finished 	ANN training loss 0.412005
# >> Epoch 119 finished 	ANN training loss 0.416960
# >> Epoch 120 finished 	ANN training loss 0.402672
# >> Epoch 121 finished 	ANN training loss 0.429768
# >> Epoch 122 finished 	ANN training loss 0.399766
# >> Epoch 123 finished 	ANN training loss 0.404039
# >> Epoch 124 finished 	ANN training loss 0.407021
# >> Epoch 125 finished 	ANN training loss 0.424109
# >> Epoch 126 finished 	ANN training loss 0.399112
# >> Epoch 127 finished 	ANN training loss 0.396412
# >> Epoch 128 finished 	ANN training loss 0.405045
# >> Epoch 129 finished 	ANN training loss 0.398563
# >> Epoch 130 finished 	ANN training loss 0.407123
# >> Epoch 131 finished 	ANN training loss 0.395103
# >> Epoch 132 finished 	ANN training loss 0.425317
# >> Epoch 133 finished 	ANN training loss 0.462791
# >> Epoch 134 finished 	ANN training loss 0.393045
# >> Epoch 135 finished 	ANN training loss 0.412132
# >> Epoch 136 finished 	ANN training loss 0.406188
# >> Epoch 137 finished 	ANN training loss 0.401952
# >> Epoch 138 finished 	ANN training loss 0.387957
# >> Epoch 139 finished 	ANN training loss 0.386106
# >> Epoch 140 finished 	ANN training loss 0.386763
# >> Epoch 141 finished 	ANN training loss 0.388939
# >> Epoch 142 finished 	ANN training loss 0.418519
# >> Epoch 143 finished 	ANN training loss 0.388107
# >> Epoch 144 finished 	ANN training loss 0.389215
# >> Epoch 145 finished 	ANN training loss 0.403695
# >> Epoch 146 finished 	ANN training loss 0.400651
# >> Epoch 147 finished 	ANN training loss 0.395142
# >> Epoch 148 finished 	ANN training loss 0.384205
# >> Epoch 149 finished 	ANN training loss 0.388123
# >> Epoch 150 finished 	ANN training loss 0.387005
# >> Epoch 151 finished 	ANN training loss 0.395987
# >> Epoch 152 finished 	ANN training loss 0.372168
# >> Epoch 153 finished 	ANN training loss 0.396364
# >> Epoch 154 finished 	ANN training loss 0.382076
# >> Epoch 155 finished 	ANN training loss 0.390983
# >> Epoch 156 finished 	ANN training loss 0.382255
# >> Epoch 157 finished 	ANN training loss 0.409561
# >> Epoch 158 finished 	ANN training loss 0.379883
# >> Epoch 159 finished 	ANN training loss 0.430516
# >> Epoch 160 finished 	ANN training loss 0.374120
# >> Epoch 161 finished 	ANN training loss 0.387442
# >> Epoch 162 finished 	ANN training loss 0.377117
# >> Epoch 163 finished 	ANN training loss 0.382582
# >> Epoch 164 finished 	ANN training loss 0.383234
# >> Epoch 165 finished 	ANN training loss 0.392476
# >> Epoch 166 finished 	ANN training loss 0.392082
# >> Epoch 167 finished 	ANN training loss 0.380976
# >> Epoch 168 finished 	ANN training loss 0.373534
# >> Epoch 169 finished 	ANN training loss 0.378650
# >> Epoch 170 finished 	ANN training loss 0.387014
# >> Epoch 171 finished 	ANN training loss 0.402184
# >> Epoch 172 finished 	ANN training loss 0.394225
# >> Epoch 173 finished 	ANN training loss 0.374872
# >> Epoch 174 finished 	ANN training loss 0.389731
# >> Epoch 175 finished 	ANN training loss 0.372044
# >> Epoch 176 finished 	ANN training loss 0.380320
# >> Epoch 177 finished 	ANN training loss 0.371508
# >> Epoch 178 finished 	ANN training loss 0.397037
# >> Epoch 179 finished 	ANN training loss 0.407633
# >> Epoch 180 finished 	ANN training loss 0.370957
# >> Epoch 181 finished 	ANN training loss 0.385020
# >> Epoch 182 finished 	ANN training loss 0.376136
# >> Epoch 183 finished 	ANN training loss 0.372608
# >> Epoch 184 finished 	ANN training loss 0.408768
# >> Epoch 185 finished 	ANN training loss 0.382676
# >> Epoch 186 finished 	ANN training loss 0.438248
# >> Epoch 187 finished 	ANN training loss 0.430770
# >> Epoch 188 finished 	ANN training loss 0.371138
# >> Epoch 189 finished 	ANN training loss 0.377466
# >> Epoch 190 finished 	ANN training loss 0.383312
# >> Epoch 191 finished 	ANN training loss 0.379406
# >> Epoch 192 finished 	ANN training loss 0.370318
# >> Epoch 193 finished 	ANN training loss 0.365817
# >> Epoch 194 finished 	ANN training loss 0.383773
# >> Epoch 195 finished 	ANN training loss 0.365928
# >> Epoch 196 finished 	ANN training loss 0.373109
# >> Epoch 197 finished 	ANN training loss 0.357505
# >> Epoch 198 finished 	ANN training loss 0.351862
# >> Epoch 199 finished 	ANN training loss 0.385658
# >> Epoch 200 finished 	ANN training loss 0.354241
# >> Epoch 201 finished 	ANN training loss 0.364506
# >> Epoch 202 finished 	ANN training loss 0.374564
# >> Epoch 203 finished 	ANN training loss 0.352800
# >> Epoch 204 finished 	ANN training loss 0.349653
# >> Epoch 205 finished 	ANN training loss 0.439244
# >> Epoch 206 finished 	ANN training loss 0.414926
# >> Epoch 207 finished 	ANN training loss 0.359209
# >> Epoch 208 finished 	ANN training loss 0.391418
# >> Epoch 209 finished 	ANN training loss 0.394839
# >> Epoch 210 finished 	ANN training loss 0.344635
# >> Epoch 211 finished 	ANN training loss 0.363488
# >> Epoch 212 finished 	ANN training loss 0.346970
# >> Epoch 213 finished 	ANN training loss 0.406993
# >> Epoch 214 finished 	ANN training loss 0.374831
# >> Epoch 215 finished 	ANN training loss 0.354156
# >> Epoch 216 finished 	ANN training loss 0.396695
# >> Epoch 217 finished 	ANN training loss 0.354305
# >> Epoch 218 finished 	ANN training loss 0.393797
# >> Epoch 219 finished 	ANN training loss 0.353698
# >> Epoch 220 finished 	ANN training loss 0.355906
# >> Epoch 221 finished 	ANN training loss 0.364303
# >> Epoch 222 finished 	ANN training loss 0.356441
# >> Epoch 223 finished 	ANN training loss 0.353727
# >> Epoch 224 finished 	ANN training loss 0.355301
# >> Epoch 225 finished 	ANN training loss 0.344843
# >> Epoch 226 finished 	ANN training loss 0.348333
# >> Epoch 227 finished 	ANN training loss 0.349296
# >> Epoch 228 finished 	ANN training loss 0.397981
# >> Epoch 229 finished 	ANN training loss 0.362640
# >> Epoch 230 finished 	ANN training loss 0.443726
# >> Epoch 231 finished 	ANN training loss 0.366241
# >> Epoch 232 finished 	ANN training loss 0.361136
# >> Epoch 233 finished 	ANN training loss 0.338854
# >> Epoch 234 finished 	ANN training loss 0.362666
# >> Epoch 235 finished 	ANN training loss 0.339829
# >> Epoch 236 finished 	ANN training loss 0.335630
# >> Epoch 237 finished 	ANN training loss 0.340180
# >> Epoch 238 finished 	ANN training loss 0.360411
# >> Epoch 239 finished 	ANN training loss 0.349563
# >> Epoch 240 finished 	ANN training loss 0.346301
# >> Epoch 241 finished 	ANN training loss 0.414783
# >> Epoch 242 finished 	ANN training loss 0.345938
# >> Epoch 243 finished 	ANN training loss 0.406763
# >> Epoch 244 finished 	ANN training loss 0.406789
# >> Epoch 245 finished 	ANN training loss 0.330571
# >> Epoch 246 finished 	ANN training loss 0.331550
# >> Epoch 247 finished 	ANN training loss 0.347142
# >> Epoch 248 finished 	ANN training loss 0.485469
# >> Epoch 249 finished 	ANN training loss 0.357263
# >> Epoch 250 finished 	ANN training loss 0.353198
# >> Epoch 251 finished 	ANN training loss 0.347653
# >> Epoch 252 finished 	ANN training loss 0.346535
# >> Epoch 253 finished 	ANN training loss 0.361575
# >> Epoch 254 finished 	ANN training loss 0.332837
# >> Epoch 255 finished 	ANN training loss 0.349726
# >> Epoch 256 finished 	ANN training loss 0.338855
# >> Epoch 257 finished 	ANN training loss 0.333772
# >> Epoch 258 finished 	ANN training loss 0.348232
# >> Epoch 259 finished 	ANN training loss 0.350072
# >> Epoch 260 finished 	ANN training loss 0.366520
# >> Epoch 261 finished 	ANN training loss 0.329816
# >> Epoch 262 finished 	ANN training loss 0.352852
# >> Epoch 263 finished 	ANN training loss 0.328173
# >> Epoch 264 finished 	ANN training loss 0.347395
# >> Epoch 265 finished 	ANN training loss 0.327546
# >> Epoch 266 finished 	ANN training loss 0.338280
# >> Epoch 267 finished 	ANN training loss 0.338273
# >> Epoch 268 finished 	ANN training loss 0.338783
# >> Epoch 269 finished 	ANN training loss 0.331989
# >> Epoch 270 finished 	ANN training loss 0.329264
# >> Epoch 271 finished 	ANN training loss 0.340076
# >> Epoch 272 finished 	ANN training loss 0.340329
# >> Epoch 273 finished 	ANN training loss 0.326568
# >> Epoch 274 finished 	ANN training loss 0.335521
# >> Epoch 275 finished 	ANN training loss 0.331734
# >> Epoch 276 finished 	ANN training loss 0.341992
# >> Epoch 277 finished 	ANN training loss 0.322696
# >> Epoch 278 finished 	ANN training loss 0.366872
# >> Epoch 279 finished 	ANN training loss 0.332598
# >> Epoch 280 finished 	ANN training loss 0.374521
# >> Epoch 281 finished 	ANN training loss 0.414045
# >> Epoch 282 finished 	ANN training loss 0.322015
# >> Epoch 283 finished 	ANN training loss 0.323554
# >> Epoch 284 finished 	ANN training loss 0.344068
# >> Epoch 285 finished 	ANN training loss 0.328907
# >> Epoch 286 finished 	ANN training loss 0.330386
# >> Epoch 287 finished 	ANN training loss 0.317090
# >> Epoch 288 finished 	ANN training loss 0.347568
# >> Epoch 289 finished 	ANN training loss 0.327406
# >> Epoch 290 finished 	ANN training loss 0.326011
# >> Epoch 291 finished 	ANN training loss 0.324926
# >> Epoch 292 finished 	ANN training loss 0.331278
# >> Epoch 293 finished 	ANN training loss 0.333363
# >> Epoch 294 finished 	ANN training loss 0.360074
# >> Epoch 295 finished 	ANN training loss 0.335459
# >> Epoch 296 finished 	ANN training loss 0.323471
# >> Epoch 297 finished 	ANN training loss 0.311717
# >> Epoch 298 finished 	ANN training loss 0.340767
# >> Epoch 299 finished 	ANN training loss 0.348663
# >> Epoch 300 finished 	ANN training loss 0.320960
# >> Epoch 301 finished 	ANN training loss 0.329298
# >> Epoch 302 finished 	ANN training loss 0.366071
# >> Epoch 303 finished 	ANN training loss 0.334263
# >> Epoch 304 finished 	ANN training loss 0.318052
# >> Epoch 305 finished 	ANN training loss 0.324370
# >> Epoch 306 finished 	ANN training loss 0.345192
# >> Epoch 307 finished 	ANN training loss 0.348468
# >> Epoch 308 finished 	ANN training loss 0.332955
# >> Epoch 309 finished 	ANN training loss 0.324076
# >> Epoch 310 finished 	ANN training loss 0.307937
# >> Epoch 311 finished 	ANN training loss 0.308203
# >> Epoch 312 finished 	ANN training loss 0.330428
# >> Epoch 313 finished 	ANN training loss 0.325274
# >> Epoch 314 finished 	ANN training loss 0.313623
# >> Epoch 315 finished 	ANN training loss 0.329456
# >> Epoch 316 finished 	ANN training loss 0.315781
# >> Epoch 317 finished 	ANN training loss 0.310755
# >> Epoch 318 finished 	ANN training loss 0.328029
# >> Epoch 319 finished 	ANN training loss 0.312920
# >> Epoch 320 finished 	ANN training loss 0.314568
# >> Epoch 321 finished 	ANN training loss 0.326467
# >> Epoch 322 finished 	ANN training loss 0.335028
# >> Epoch 323 finished 	ANN training loss 0.302413
# >> Epoch 324 finished 	ANN training loss 0.332264
# >> Epoch 325 finished 	ANN training loss 0.316071
# >> Epoch 326 finished 	ANN training loss 0.328458
# >> Epoch 327 finished 	ANN training loss 0.332720
# >> Epoch 328 finished 	ANN training loss 0.327266
# >> Epoch 329 finished 	ANN training loss 0.328988
# >> Epoch 330 finished 	ANN training loss 0.328443
# >> Epoch 331 finished 	ANN training loss 0.314832
# >> Epoch 332 finished 	ANN training loss 0.347019
# >> Epoch 333 finished 	ANN training loss 0.323796
# >> Epoch 334 finished 	ANN training loss 0.319877
# >> Epoch 335 finished 	ANN training loss 0.314236
# >> Epoch 336 finished 	ANN training loss 0.379214
# >> Epoch 337 finished 	ANN training loss 0.304239
# >> Epoch 338 finished 	ANN training loss 0.331202
# >> Epoch 339 finished 	ANN training loss 0.317784
# >> Epoch 340 finished 	ANN training loss 0.327815
# >> Epoch 341 finished 	ANN training loss 0.304967
# >> Epoch 342 finished 	ANN training loss 0.297634
# >> Epoch 343 finished 	ANN training loss 0.352690
# >> Epoch 344 finished 	ANN training loss 0.311668
# >> Epoch 345 finished 	ANN training loss 0.400103
# >> Epoch 346 finished 	ANN training loss 0.292006
# >> Epoch 347 finished 	ANN training loss 0.297568
# >> Epoch 348 finished 	ANN training loss 0.311391
# >> Epoch 349 finished 	ANN training loss 0.331345
# >> Epoch 350 finished 	ANN training loss 0.306693
# >> Epoch 351 finished 	ANN training loss 0.304306
# >> Epoch 352 finished 	ANN training loss 0.306295
# >> Epoch 353 finished 	ANN training loss 0.301561
# >> Epoch 354 finished 	ANN training loss 0.302118
# >> Epoch 355 finished 	ANN training loss 0.308115
# >> Epoch 356 finished 	ANN training loss 0.322247
# >> Epoch 357 finished 	ANN training loss 0.314369
# >> Epoch 358 finished 	ANN training loss 0.297010
# >> Epoch 359 finished 	ANN training loss 0.297379
# >> Epoch 360 finished 	ANN training loss 0.317448
# >> Epoch 361 finished 	ANN training loss 0.292753
# >> Epoch 362 finished 	ANN training loss 0.296901
# >> Epoch 363 finished 	ANN training loss 0.298222
# >> Epoch 364 finished 	ANN training loss 0.307112
# >> Epoch 365 finished 	ANN training loss 0.298166
# >> Epoch 366 finished 	ANN training loss 0.289281
# >> Epoch 367 finished 	ANN training loss 0.328836
# >> Epoch 368 finished 	ANN training loss 0.316245
# >> Epoch 369 finished 	ANN training loss 0.289119
# >> Epoch 370 finished 	ANN training loss 0.303670
# >> Epoch 371 finished 	ANN training loss 0.311696
# >> Epoch 372 finished 	ANN training loss 0.307364
# >> Epoch 373 finished 	ANN training loss 0.311548
# >> Epoch 374 finished 	ANN training loss 0.291961
# >> Epoch 375 finished 	ANN training loss 0.357163
# >> Epoch 376 finished 	ANN training loss 0.289435
# >> Epoch 377 finished 	ANN training loss 0.303567
# >> Epoch 378 finished 	ANN training loss 0.310302
# >> Epoch 379 finished 	ANN training loss 0.295616
# >> Epoch 380 finished 	ANN training loss 0.304135
# >> Epoch 381 finished 	ANN training loss 0.291146
# >> Epoch 382 finished 	ANN training loss 0.285113
# >> Epoch 383 finished 	ANN training loss 0.342848
# >> Epoch 384 finished 	ANN training loss 0.292000
# >> Epoch 385 finished 	ANN training loss 0.302887
# >> Epoch 386 finished 	ANN training loss 0.317181
# >> Epoch 387 finished 	ANN training loss 0.324180
# >> Epoch 388 finished 	ANN training loss 0.298265
# >> Epoch 389 finished 	ANN training loss 0.294184
# >> Epoch 390 finished 	ANN training loss 0.327874
# >> Epoch 391 finished 	ANN training loss 0.301541
# >> Epoch 392 finished 	ANN training loss 0.303408
# >> Epoch 393 finished 	ANN training loss 0.287188
# >> Epoch 394 finished 	ANN training loss 0.311818
# >> Epoch 395 finished 	ANN training loss 0.316718
# >> Epoch 396 finished 	ANN training loss 0.281935
# >> Epoch 397 finished 	ANN training loss 0.296218
# >> Epoch 398 finished 	ANN training loss 0.300652
# >> Epoch 399 finished 	ANN training loss 0.280795
# >> Epoch 400 finished 	ANN training loss 0.307892
# >> Epoch 401 finished 	ANN training loss 0.274179
# >> Epoch 402 finished 	ANN training loss 0.293814
# >> Epoch 403 finished 	ANN training loss 0.297580
# >> Epoch 404 finished 	ANN training loss 0.290167
# >> Epoch 405 finished 	ANN training loss 0.298990
# >> Epoch 406 finished 	ANN training loss 0.294310
# >> Epoch 407 finished 	ANN training loss 0.294579
# >> Epoch 408 finished 	ANN training loss 0.296803
# >> Epoch 409 finished 	ANN training loss 0.292410
# >> Epoch 410 finished 	ANN training loss 0.270186
# >> Epoch 411 finished 	ANN training loss 0.270479
# >> Epoch 412 finished 	ANN training loss 0.276224
# >> Epoch 413 finished 	ANN training loss 0.279405
# >> Epoch 414 finished 	ANN training loss 0.312952
# >> Epoch 415 finished 	ANN training loss 0.265100
# >> Epoch 416 finished 	ANN training loss 0.286015
# >> Epoch 417 finished 	ANN training loss 0.297843
# >> Epoch 418 finished 	ANN training loss 0.315591
# >> Epoch 419 finished 	ANN training loss 0.300244
# >> Epoch 420 finished 	ANN training loss 0.275300
# >> Epoch 421 finished 	ANN training loss 0.279035
# >> Epoch 422 finished 	ANN training loss 0.275428
# >> Epoch 423 finished 	ANN training loss 0.293485
# >> Epoch 424 finished 	ANN training loss 0.317120
# >> Epoch 425 finished 	ANN training loss 0.282990
# >> Epoch 426 finished 	ANN training loss 0.268672
# >> Epoch 427 finished 	ANN training loss 0.310055
# >> Epoch 428 finished 	ANN training loss 0.285798
# >> Epoch 429 finished 	ANN training loss 0.272654
# >> Epoch 430 finished 	ANN training loss 0.299025
# >> Epoch 431 finished 	ANN training loss 0.284247
# >> Epoch 432 finished 	ANN training loss 0.279197
# >> Epoch 433 finished 	ANN training loss 0.299169
# >> Epoch 434 finished 	ANN training loss 0.280059
# >> Epoch 435 finished 	ANN training loss 0.284055
# >> Epoch 436 finished 	ANN training loss 0.296590
# >> Epoch 437 finished 	ANN training loss 0.288293
# >> Epoch 438 finished 	ANN training loss 0.337530
# >> Epoch 439 finished 	ANN training loss 0.282262
# >> Epoch 440 finished 	ANN training loss 0.284577
# >> Epoch 441 finished 	ANN training loss 0.256756
# >> Epoch 442 finished 	ANN training loss 0.264627
# >> Epoch 443 finished 	ANN training loss 0.289345
# >> Epoch 444 finished 	ANN training loss 0.335617
# >> Epoch 445 finished 	ANN training loss 0.305392
# >> Epoch 446 finished 	ANN training loss 0.289612
# >> Epoch 447 finished 	ANN training loss 0.300797
# >> Epoch 448 finished 	ANN training loss 0.264232
# >> Epoch 449 finished 	ANN training loss 0.289982
# >> Epoch 450 finished 	ANN training loss 0.269937
# >> Epoch 451 finished 	ANN training loss 0.278913
# >> Epoch 452 finished 	ANN training loss 0.280561
# >> Epoch 453 finished 	ANN training loss 0.258369
# >> Epoch 454 finished 	ANN training loss 0.272544
# >> Epoch 455 finished 	ANN training loss 0.289747
# >> Epoch 456 finished 	ANN training loss 0.263467
# >> Epoch 457 finished 	ANN training loss 0.261372
# >> Epoch 458 finished 	ANN training loss 0.280705
# >> Epoch 459 finished 	ANN training loss 0.274217
# >> Epoch 460 finished 	ANN training loss 0.299020
# >> Epoch 461 finished 	ANN training loss 0.276056
# >> Epoch 462 finished 	ANN training loss 0.252919
# >> Epoch 463 finished 	ANN training loss 0.279337
# >> Epoch 464 finished 	ANN training loss 0.270065
# >> Epoch 465 finished 	ANN training loss 0.263628
# >> Epoch 466 finished 	ANN training loss 0.292304
# >> Epoch 467 finished 	ANN training loss 0.276540
# >> Epoch 468 finished 	ANN training loss 0.265631
# >> Epoch 469 finished 	ANN training loss 0.264006
# >> Epoch 470 finished 	ANN training loss 0.247827
# >> Epoch 471 finished 	ANN training loss 0.264556
# >> Epoch 472 finished 	ANN training loss 0.260417
# >> Epoch 473 finished 	ANN training loss 0.265839
# >> Epoch 474 finished 	ANN training loss 0.265140
# >> Epoch 475 finished 	ANN training loss 0.321830
# >> Epoch 476 finished 	ANN training loss 0.270746
# >> Epoch 477 finished 	ANN training loss 0.259396
# >> Epoch 478 finished 	ANN training loss 0.256990
# >> Epoch 479 finished 	ANN training loss 0.268841
# >> Epoch 480 finished 	ANN training loss 0.275963
# >> Epoch 481 finished 	ANN training loss 0.259117
# >> Epoch 482 finished 	ANN training loss 0.257636
# >> Epoch 483 finished 	ANN training loss 0.267923
# >> Epoch 484 finished 	ANN training loss 0.255203
# >> Epoch 485 finished 	ANN training loss 0.248000
# >> Epoch 486 finished 	ANN training loss 0.264498
# >> Epoch 487 finished 	ANN training loss 0.274674
# >> Epoch 488 finished 	ANN training loss 0.259644
# >> Epoch 489 finished 	ANN training loss 0.247304
# >> Epoch 490 finished 	ANN training loss 0.260386
# >> Epoch 491 finished 	ANN training loss 0.257980
# >> Epoch 492 finished 	ANN training loss 0.244117
# >> Epoch 493 finished 	ANN training loss 0.249796
# >> Epoch 494 finished 	ANN training loss 0.258685
# >> Epoch 495 finished 	ANN training loss 0.273906
# >> Epoch 496 finished 	ANN training loss 0.269504
# >> Epoch 497 finished 	ANN training loss 0.259631
# >> Epoch 498 finished 	ANN training loss 0.249951
# >> Epoch 499 finished 	ANN training loss 0.267934
# [END] Fine tuning step
# SupervisedDBNClassification(batch_size=20, dropout_p=0,
#                             idx_to_label_map={0: 0, 1: 1},
#                             l2_regularization=1.0,
#                             label_to_idx_map={0: 0, 1: 1}, learning_rate=0.15,
#                             n_iter_backprop=500, verbose=True)

# %%
# Test
#Y的结果预测值
Y_pred = classifier.predict(X_test[:,2:])

#对应类别的概率
#二分类
Y_pred_p = classifier.predict_proba(X_test[:,2:])[:,1]
#多分类
#Y_pred_p = classifier.predict_proba_dict(X_test[:,2:])[:]

#转换成数组
Y_pred = np.array(Y_pred)
Y_test_1 = np.array(Y_test)
##Y_pred_p = np.array(Y_pred_p)
Y_pred_1 = np.reshape(Y_pred,(len(Y_pred),1))
Y_test_1 = np.reshape(Y_test_1,(len(Y_test_1),1))
##Y_pred_p = np.reshape(Y_pred_p,(len(Y_pred_p),1))
#Y_pred_1

print('Done.\nAccuracy: %f' % accuracy_score(Y_test, Y_pred))
print('Done.\nprecision_score: %f' % precision_score(Y_test, Y_pred))
print('Done.\nrecall_score: %f' % recall_score(Y_test, Y_pred))
print('Done.\nf1_score: %f' % f1_score(Y_test, Y_pred))
print('Done.\nconfusion_matrix: ' )
print(confusion_matrix(Y_test, Y_pred))
print('Done.\ncohen_kappa_score: %f' % cohen_kappa_score(Y_test, Y_pred))
print('Done.\nhamming_loss: %f' % hamming_loss(Y_test, Y_pred))
fpr,tpr,threshold= roc_curve(Y_test,Y_pred_p)
#print('Done.\nauc: %f' % auc(fpr, tpr))
##target_names = ['class 0','class 1','class 2', 'class 3']
##print(classification_report(Y_test, Y_pred, target_names=target_names))
# Out:
# Done.
# Accuracy: 0.796610
# Done.
# precision_score: 0.762058
# Done.
# recall_score: 0.874539
# Done.
# f1_score: 0.814433
# Done.
# confusion_matrix:
# [[186  74]
#  [ 34 237]]
# Done.
# cohen_kappa_score: 0.591771
# Done.
# hamming_loss: 0.203390

# %%
# Test
y_pred = classifier.predict(x_[:,2:])
y_pred_p = classifier.predict_proba(x_[:,2:])[:,1]
y_pred = np.array(y_pred)
y_test_1 = np.array(y_)
##y_pred_p = np.array(y_pred_p) 
y_pred_1 = np.reshape(y_pred,(len(y_pred),1))
y_test_1 = np.reshape(y_test_1,(len(y_test_1),1))
##y_pred_p = np.reshape(y_pred_p,(len(y_pred_p),1))

# %%
all_save_data = np.concatenate((res,y_test_1),axis=1)
mode=0
if mode==0:
    all_save_data = np.concatenate((all_save_data,y_pred_1),axis=1)
else:
    all_save_data = np.concatenate((all_save_data,y_pred_p),axis=1)
all_save_data_pd = pd.DataFrame(all_save_data,columns=['x','y','road','PGA',
 'river','fault','lithology','NDVI','Ht','landslide','predict'])
 # np.savetxt('data.csv',all_save_data,delimiter=',')
all_save_data_pd.to_csv('result.csv',index=True)
# y_test_1.shape

# %%
##0.3部分ROC
precision, recall, thresholds = precision_recall_curve(np.array(Y_test),Y_pred_p)
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(fpr,tpr)#数据输入
plt.plot([0,1],[0,1],linestyle='--')#直线
plt.xlabel('False Postive Rate')#x坐标
plt.ylabel('True Positive Rate')#y坐标
plt.grid()#网格
plt.show()
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(precision,recall)#数据输入
plt.plot([0,1],[1,0],linestyle='--')#直线
plt.xlabel('recall')#x坐标
plt.ylabel('precision')#y坐标
plt.grid()#网格
plt.show()

# %%
##0.7ROC
Y_pred = classifier.predict(X_train[:,2:])####训练数据
Y_pred_p = classifier.predict_proba(X_train[:,2:])[:,1]

fpr,tpr,threshold= roc_curve(Y_train,Y_pred_p)
precision, recall, thresholds = precision_recall_curve(np.array(Y_train),Y_pred_p)
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(fpr,tpr)#数据输入
plt.plot([0,1],[0,1],linestyle='--')#直线
plt.xlabel('False Postive Rate')#x坐标
plt.ylabel('True Positive Rate')#y坐标
plt.grid()#网格
plt.show()
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(precision,recall)#数据输入
plt.plot([0,1],[1,0],linestyle='--')#直线
plt.xlabel('recall')#x坐标
plt.ylabel('precision')#y坐标
plt.grid()#网格
plt.show()
