# %%
import numpy as np

np.random.seed(1337)  # for reproducibility
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score,confusion_matrix,f1_score,precision_score
from sklearn.metrics import cohen_kappa_score,hamming_loss,precision_recall_curve
from sklearn.metrics import roc_curve,auc
#分类报告
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from dbn.tensorflow import SupervisedDBNClassification
import tensorflow._api.v2.compat.v1 as tf
#import tensorflow.compat.v1 as tf ###
#tf.disable_v2_behavior()
import  pandas as pd
#import eli5
#from eli5.sklearn import PermutationImportance
#import shap
from sklearn.preprocessing import normalize
from sklearn.preprocessing import MinMaxScaler

print(tf.__version__)
# Out:
# WARNING:tensorflow:From E:\anaconda\envs\tensor241\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2.3.0

# %%
# Loading dataset
# digits = load_digits()
# X, Y = digits.data, digits.target
#data = pd.read_csv(r'Ctrain.csv',sep=',')
data = pd.read_csv(r'train.csv',sep=',')
data_= pd.read_csv(r'test4.csv',sep=',')
data_.dropna(inplace=True)
#导入数据
label_index = 7
dim  = 7
# data[label_index] = data[label_index].map({1:1, 2:-1})
data = data.sample(frac=1.0)
data = data.reset_index()
x = data.drop(['landslide'],axis=1)
print(x.shape)
x = x.drop(['index'],axis=1)
x = np.array(x)
print(x.shape)
std=MinMaxScaler((0,1))
x=std.fit_transform(x)
y = data['landslide']
y = pd.to_numeric( y, errors='coerce').fillna('0').astype('int32')
# Data scaling
# X = (X / 16).astype(np.float32)
# Out:
# (1770, 10)
# (1770, 9)

# %%
#训练
data_ = data_.sample(frac=1.0)
data_ = data_.reset_index()
x_ = data_.drop(['landslide','pre1'],axis=1)
x_ = x_.drop(['index'],axis=1)
x_ = np.array(x_)
res=x_
print(x_.shape)
std=MinMaxScaler((0,1))
x_=std.fit_transform(x_)
y_ = data_['landslide']
y_ = pd.to_numeric( y_, errors='coerce').fillna('0').astype('int32')

# %%
# Splitting data
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=1)#random_state=0
X_train[:,2:]
# Training
classifier = SupervisedDBNClassification(hidden_layers_structure=[100, 100],
                                         learning_rate_rbm=0.07, 
                                         learning_rate=0.15,
                                         n_epochs_rbm=16,
                                         n_iter_backprop=500,
                                         batch_size=20,
                                         activation_function='relu',
                                         dropout_p=0)
classifier.fit(X_train[:,2:], Y_train)
# Out:
# [START] Pre-training step:
# WARNING:tensorflow:From C:\Users\JIACTX\Desktop\2class\dbn\tensorflow\models.py:151: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# >> Epoch 1 finished 	RBM Reconstruction error 0.318164
# >> Epoch 2 finished 	RBM Reconstruction error 0.225892
# >> Epoch 3 finished 	RBM Reconstruction error 0.179893
# >> Epoch 4 finished 	RBM Reconstruction error 0.176083
# >> Epoch 5 finished 	RBM Reconstruction error 0.140027
# >> Epoch 6 finished 	RBM Reconstruction error 0.133911
# >> Epoch 7 finished 	RBM Reconstruction error 0.132734
# >> Epoch 8 finished 	RBM Reconstruction error 0.110152
# >> Epoch 9 finished 	RBM Reconstruction error 0.098869
# >> Epoch 10 finished 	RBM Reconstruction error 0.117947
# >> Epoch 11 finished 	RBM Reconstruction error 0.102989
# >> Epoch 12 finished 	RBM Reconstruction error 0.102539
# >> Epoch 13 finished 	RBM Reconstruction error 0.120334
# >> Epoch 14 finished 	RBM Reconstruction error 0.132873
# >> Epoch 15 finished 	RBM Reconstruction error 0.113296
# >> Epoch 16 finished 	RBM Reconstruction error 0.138919
# >> Epoch 1 finished 	RBM Reconstruction error 0.285676
# >> Epoch 2 finished 	RBM Reconstruction error 0.261189
# >> Epoch 3 finished 	RBM Reconstruction error 0.267206
# >> Epoch 4 finished 	RBM Reconstruction error 0.235407
# >> Epoch 5 finished 	RBM Reconstruction error 0.237474
# >> Epoch 6 finished 	RBM Reconstruction error 0.285701
# >> Epoch 7 finished 	RBM Reconstruction error 0.259634
# >> Epoch 8 finished 	RBM Reconstruction error 0.362972
# >> Epoch 9 finished 	RBM Reconstruction error 0.340451
# >> Epoch 10 finished 	RBM Reconstruction error 0.277882
# >> Epoch 11 finished 	RBM Reconstruction error 0.454625
# >> Epoch 12 finished 	RBM Reconstruction error 0.715709
# >> Epoch 13 finished 	RBM Reconstruction error 0.781748
# >> Epoch 14 finished 	RBM Reconstruction error 0.626968
# >> Epoch 15 finished 	RBM Reconstruction error 0.771136
# >> Epoch 16 finished 	RBM Reconstruction error 1.267933
# [END] Pre-training step
# WARNING:tensorflow:From E:\anaconda\envs\tensor241\lib\site-packages\tensorflow\python\util\dispatch.py:201: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# [START] Fine tuning step:
# >> Epoch 0 finished 	ANN training loss 0.666238
# >> Epoch 1 finished 	ANN training loss 0.623944
# >> Epoch 2 finished 	ANN training loss 0.611703
# >> Epoch 3 finished 	ANN training loss 0.583000
# >> Epoch 4 finished 	ANN training loss 0.584352
# >> Epoch 5 finished 	ANN training loss 0.579889
# >> Epoch 6 finished 	ANN training loss 0.597964
# >> Epoch 7 finished 	ANN training loss 0.563200
# >> Epoch 8 finished 	ANN training loss 0.563111
# >> Epoch 9 finished 	ANN training loss 0.547836
# >> Epoch 10 finished 	ANN training loss 0.538808
# >> Epoch 11 finished 	ANN training loss 0.535632
# >> Epoch 12 finished 	ANN training loss 0.536545
# >> Epoch 13 finished 	ANN training loss 0.521947
# >> Epoch 14 finished 	ANN training loss 0.565128
# >> Epoch 15 finished 	ANN training loss 0.511062
# >> Epoch 16 finished 	ANN training loss 0.543716
# >> Epoch 17 finished 	ANN training loss 0.505183
# >> Epoch 18 finished 	ANN training loss 0.510423
# >> Epoch 19 finished 	ANN training loss 0.511083
# >> Epoch 20 finished 	ANN training loss 0.493625
# >> Epoch 21 finished 	ANN training loss 0.515802
# >> Epoch 22 finished 	ANN training loss 0.486868
# >> Epoch 23 finished 	ANN training loss 0.504021
# >> Epoch 24 finished 	ANN training loss 0.504328
# >> Epoch 25 finished 	ANN training loss 0.489443
# >> Epoch 26 finished 	ANN training loss 0.499372
# >> Epoch 27 finished 	ANN training loss 0.491159
# >> Epoch 28 finished 	ANN training loss 0.491001
# >> Epoch 29 finished 	ANN training loss 0.522546
# >> Epoch 30 finished 	ANN training loss 0.482501
# >> Epoch 31 finished 	ANN training loss 0.481323
# >> Epoch 32 finished 	ANN training loss 0.478111
# >> Epoch 33 finished 	ANN training loss 0.479225
# >> Epoch 34 finished 	ANN training loss 0.475620
# >> Epoch 35 finished 	ANN training loss 0.621006
# >> Epoch 345 finished 	ANN training loss 0.443126
# >> Epoch 346 finished 	ANN training loss 0.285037
# >> Epoch 347 finished 	ANN training loss 0.266046
# >> Epoch 348 finished 	ANN training loss 0.281496
# >> Epoch 349 finished 	ANN training loss 0.304740
# >> Epoch 350 finished 	ANN training loss 0.289411
# >> Epoch 351 finished 	ANN training loss 0.277596
# >> Epoch 352 finished 	ANN training loss 0.284271
# >> Epoch 353 finished 	ANN training loss 0.265088
# >> Epoch 354 finished 	ANN training loss 0.277983
# >> Epoch 355 finished 	ANN training loss 0.300605
# >> Epoch 356 finished 	ANN training loss 0.284905
# >> Epoch 357 finished 	ANN training loss 0.279741
# >> Epoch 358 finished 	ANN training loss 0.282391
# >> Epoch 359 finished 	ANN training loss 0.304091
# >> Epoch 360 finished 	ANN training loss 0.279082
# >> Epoch 361 finished 	ANN training loss 0.274600
# >> Epoch 362 finished 	ANN training loss 0.282334
# >> Epoch 363 finished 	ANN training loss 0.278193
# >> Epoch 364 finished 	ANN training loss 0.286760
# >> Epoch 365 finished 	ANN training loss 0.278442
# >> Epoch 366 finished 	ANN training loss 0.291500
# >> Epoch 367 finished 	ANN training loss 0.305351
# >> Epoch 368 finished 	ANN training loss 0.299774
# >> Epoch 369 finished 	ANN training loss 0.273426
# >> Epoch 370 finished 	ANN training loss 0.300301
# >> Epoch 371 finished 	ANN training loss 0.270775
# >> Epoch 372 finished 	ANN training loss 0.278673
# >> Epoch 373 finished 	ANN training loss 0.298015
# >> Epoch 374 finished 	ANN training loss 0.264886
# >> Epoch 375 finished 	ANN training loss 0.294719
# >> Epoch 376 finished 	ANN training loss 0.281275
# >> Epoch 377 finished 	ANN training loss 0.286724
# >> Epoch 378 finished 	ANN training loss 0.279878
# >> Epoch 379 finished 	ANN training loss 0.275217
# >> Epoch 380 finished 	ANN training loss 0.280323
# >> Epoch 381 finished 	ANN training loss 0.280201
# >> Epoch 382 finished 	ANN training loss 0.277573
# >> Epoch 383 finished 	ANN training loss 0.311463
# >> Epoch 384 finished 	ANN training loss 0.284934
# >> Epoch 385 finished 	ANN training loss 0.299541
# >> Epoch 386 finished 	ANN training loss 0.289688
# >> Epoch 387 finished 	ANN training loss 0.310251
# >> Epoch 388 finished 	ANN training loss 0.279120
# >> Epoch 389 finished 	ANN training loss 0.269036
# >> Epoch 390 finished 	ANN training loss 0.264521
# >> Epoch 391 finished 	ANN training loss 0.283246
# >> Epoch 392 finished 	ANN training loss 0.279788
# >> Epoch 393 finished 	ANN training loss 0.270611
# >> Epoch 394 finished 	ANN training loss 0.269592
# >> Epoch 395 finished 	ANN training loss 0.296937
# >> Epoch 396 finished 	ANN training loss 0.257174
# >> Epoch 397 finished 	ANN training loss 0.264536
# >> Epoch 398 finished 	ANN training loss 0.296978
# >> Epoch 399 finished 	ANN training loss 0.261252
# >> Epoch 400 finished 	ANN training loss 0.262176
# >> Epoch 401 finished 	ANN training loss 0.253730
# >> Epoch 402 finished 	ANN training loss 0.259665
# >> Epoch 403 finished 	ANN training loss 0.257798
# >> Epoch 404 finished 	ANN training loss 0.268452
# >> Epoch 405 finished 	ANN training loss 0.266160
# >> Epoch 406 finished 	ANN training loss 0.256421
# >> Epoch 407 finished 	ANN training loss 0.276505
# >> Epoch 408 finished 	ANN training loss 0.277612
# >> Epoch 409 finished 	ANN training loss 0.278499
# >> Epoch 410 finished 	ANN training loss 0.252699
# >> Epoch 411 finished 	ANN training loss 0.265045
# >> Epoch 412 finished 	ANN training loss 0.250808
# >> Epoch 413 finished 	ANN training loss 0.257864
# >> Epoch 414 finished 	ANN training loss 0.253175
# >> Epoch 415 finished 	ANN training loss 0.272542
# >> Epoch 416 finished 	ANN training loss 0.265396
# >> Epoch 417 finished 	ANN training loss 0.253462
# >> Epoch 418 finished 	ANN training loss 0.281823
# >> Epoch 419 finished 	ANN training loss 0.252452
# >> Epoch 420 finished 	ANN training loss 0.253285
# >> Epoch 421 finished 	ANN training loss 0.257191
# >> Epoch 422 finished 	ANN training loss 0.238433
# >> Epoch 423 finished 	ANN training loss 0.360718
# >> Epoch 424 finished 	ANN training loss 0.279992
# >> Epoch 425 finished 	ANN training loss 0.251839
# >> Epoch 426 finished 	ANN training loss 0.257682
# >> Epoch 427 finished 	ANN training loss 0.256377
# >> Epoch 428 finished 	ANN training loss 0.281447
# >> Epoch 429 finished 	ANN training loss 0.246178
# >> Epoch 430 finished 	ANN training loss 0.308151
# >> Epoch 431 finished 	ANN training loss 0.261824
# >> Epoch 432 finished 	ANN training loss 0.255097
# >> Epoch 433 finished 	ANN training loss 0.289573
# >> Epoch 434 finished 	ANN training loss 0.262631
# >> Epoch 435 finished 	ANN training loss 0.284829
# >> Epoch 436 finished 	ANN training loss 0.249601
# >> Epoch 437 finished 	ANN training loss 0.251732
# >> Epoch 438 finished 	ANN training loss 0.288502
# >> Epoch 439 finished 	ANN training loss 0.257217
# >> Epoch 440 finished 	ANN training loss 0.268607
# >> Epoch 441 finished 	ANN training loss 0.257359
# >> Epoch 442 finished 	ANN training loss 0.255470
# >> Epoch 443 finished 	ANN training loss 0.258107
# >> Epoch 444 finished 	ANN training loss 0.296871
# >> Epoch 445 finished 	ANN training loss 0.260714
# >> Epoch 446 finished 	ANN training loss 0.268161
# >> Epoch 447 finished 	ANN training loss 0.262162
# >> Epoch 448 finished 	ANN training loss 0.248061
# >> Epoch 449 finished 	ANN training loss 0.262973
# >> Epoch 450 finished 	ANN training loss 0.287851
# >> Epoch 451 finished 	ANN training loss 0.273023
# >> Epoch 452 finished 	ANN training loss 0.252029
# >> Epoch 453 finished 	ANN training loss 0.242783
# >> Epoch 454 finished 	ANN training loss 0.248994
# >> Epoch 455 finished 	ANN training loss 0.284189
# >> Epoch 456 finished 	ANN training loss 0.247940
# >> Epoch 457 finished 	ANN training loss 0.239037
# >> Epoch 458 finished 	ANN training loss 0.281392
# >> Epoch 459 finished 	ANN training loss 0.243277
# >> Epoch 460 finished 	ANN training loss 0.268765
# >> Epoch 461 finished 	ANN training loss 0.253266
# >> Epoch 462 finished 	ANN training loss 0.232222
# >> Epoch 463 finished 	ANN training loss 0.246855
# >> Epoch 464 finished 	ANN training loss 0.244869
# >> Epoch 465 finished 	ANN training loss 0.247885
# >> Epoch 466 finished 	ANN training loss 0.276937
# >> Epoch 467 finished 	ANN training loss 0.262666
# >> Epoch 468 finished 	ANN training loss 0.284853
# >> Epoch 469 finished 	ANN training loss 0.235060
# >> Epoch 470 finished 	ANN training loss 0.227691
# >> Epoch 471 finished 	ANN training loss 0.241649
# >> Epoch 472 finished 	ANN training loss 0.270558
# >> Epoch 473 finished 	ANN training loss 0.236769
# >> Epoch 474 finished 	ANN training loss 0.280399
# >> Epoch 475 finished 	ANN training loss 0.256273
# >> Epoch 476 finished 	ANN training loss 0.225832
# >> Epoch 477 finished 	ANN training loss 0.240114
# >> Epoch 478 finished 	ANN training loss 0.237729
# >> Epoch 479 finished 	ANN training loss 0.254846
# >> Epoch 480 finished 	ANN training loss 0.275890
# >> Epoch 481 finished 	ANN training loss 0.228632
# >> Epoch 482 finished 	ANN training loss 0.223430
# >> Epoch 483 finished 	ANN training loss 0.248564
# >> Epoch 484 finished 	ANN training loss 0.248555
# >> Epoch 485 finished 	ANN training loss 0.229548
# >> Epoch 486 finished 	ANN training loss 0.230048
# >> Epoch 487 finished 	ANN training loss 0.263875
# >> Epoch 488 finished 	ANN training loss 0.286215
# >> Epoch 489 finished 	ANN training loss 0.243263
# >> Epoch 490 finished 	ANN training loss 0.231019
# >> Epoch 491 finished 	ANN training loss 0.245889
# >> Epoch 492 finished 	ANN training loss 0.265491
# >> Epoch 493 finished 	ANN training loss 0.254008
# >> Epoch 494 finished 	ANN training loss 0.264279
# >> Epoch 495 finished 	ANN training loss 0.243307
# >> Epoch 496 finished 	ANN training loss 0.246808
# >> Epoch 497 finished 	ANN training loss 0.251880
# >> Epoch 498 finished 	ANN training loss 0.239882
# >> Epoch 499 finished 	ANN training loss 0.251398
# [END] Fine tuning step
# SupervisedDBNClassification(batch_size=20, dropout_p=0,
#                             idx_to_label_map={0: 0, 1: 1},
#                             l2_regularization=1.0,
#                             label_to_idx_map={0: 0, 1: 1}, learning_rate=0.15,
#                             n_iter_backprop=500, verbose=True)

# %%
# Test
#Y的结果预测值
Y_pred = classifier.predict(X_test[:,2:])

#对应类别的概率
#二分类
Y_pred_p = classifier.predict_proba(X_test[:,2:])[:,1]
#多分类
#Y_pred_p = classifier.predict_proba_dict(X_test[:,2:])[:]

#转换成数组
Y_pred = np.array(Y_pred)
Y_test_1 = np.array(Y_test)
##Y_pred_p = np.array(Y_pred_p)
Y_pred_1 = np.reshape(Y_pred,(len(Y_pred),1))
Y_test_1 = np.reshape(Y_test_1,(len(Y_test_1),1))
##Y_pred_p = np.reshape(Y_pred_p,(len(Y_pred_p),1))
#Y_pred_1

print('Done.\nAccuracy: %f' % accuracy_score(Y_test, Y_pred))
print('Done.\nprecision_score: %f' % precision_score(Y_test, Y_pred))
print('Done.\nrecall_score: %f' % recall_score(Y_test, Y_pred))
print('Done.\nf1_score: %f' % f1_score(Y_test, Y_pred))
print('Done.\nconfusion_matrix: ' )
print(confusion_matrix(Y_test, Y_pred))
print('Done.\ncohen_kappa_score: %f' % cohen_kappa_score(Y_test, Y_pred))
print('Done.\nhamming_loss: %f' % hamming_loss(Y_test, Y_pred))
fpr,tpr,threshold= roc_curve(Y_test,Y_pred_p)
#print('Done.\nauc: %f' % auc(fpr, tpr))
##target_names = ['class 0','class 1','class 2', 'class 3']
##print(classification_report(Y_test, Y_pred, target_names=target_names))
# Out:
# Done.
# Accuracy: 0.802260
# Done.
# precision_score: 0.761006
# Done.
# recall_score: 0.892989
# Done.
# f1_score: 0.821732
# Done.
# confusion_matrix:
# [[184  76]
#  [ 29 242]]
# Done.
# cohen_kappa_score: 0.602893
# Done.
# hamming_loss: 0.197740

# %%
# Test
y_pred = classifier.predict(x_[:,2:])
y_pred_p = classifier.predict_proba(x_[:,2:])[:,1]
y_pred = np.array(y_pred)
y_test_1 = np.array(y_)
##y_pred_p = np.array(y_pred_p) 
y_pred_1 = np.reshape(y_pred,(len(y_pred),1))
y_test_1 = np.reshape(y_test_1,(len(y_test_1),1))
##y_pred_p = np.reshape(y_pred_p,(len(y_pred_p),1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c74553024330> in <module>
#       1 # Test
# ----> 2 y_pred = classifier.predict(x_[:,2:])
#       3 y_pred_p = classifier.predict_proba(x_[:,2:])[:,1]
#       4 y_pred = np.array(y_pred)
#       5 y_test_1 = np.array(y_)
#
# NameError: name 'x_' is not defined

# %%
all_save_data = np.concatenate((res,y_test_1),axis=1)
mode=0
if mode==0:
    all_save_data = np.concatenate((all_save_data,y_pred_1),axis=1)
else:
    all_save_data = np.concatenate((all_save_data,y_pred_p),axis=1)
all_save_data_pd = pd.DataFrame(all_save_data,columns=['x','y','road','PGA',
 'river','fault','lithology','NDVI','Ht','landslide','predict'])
 # np.savetxt('data.csv',all_save_data,delimiter=',')
all_save_data_pd.to_csv('result.csv',index=True)
# y_test_1.shape

# %%
##0.3部分ROC
precision, recall, thresholds = precision_recall_curve(np.array(Y_test),Y_pred_p)
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(fpr,tpr)#数据输入
plt.plot([0,1],[0,1],linestyle='--')#直线
plt.xlabel('False Postive Rate')#x坐标
plt.ylabel('True Positive Rate')#y坐标
plt.grid()#网格
plt.show()
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(precision,recall)#数据输入
plt.plot([0,1],[1,0],linestyle='--')#直线
plt.xlabel('recall')#x坐标
plt.ylabel('precision')#y坐标
plt.grid()#网格
plt.show()

# %%
##0.7ROC
Y_pred = classifier.predict(X_train[:,2:])####训练数据
Y_pred_p = classifier.predict_proba(X_train[:,2:])[:,1]
print('Done.\nconfusion_matrix: ' )
print(confusion_matrix(Y_train, Y_pred))
print('Done.\ncohen_kappa_score: %f' % cohen_kappa_score(Y_train, Y_pred))

fpr,tpr,threshold= roc_curve(Y_train,Y_pred_p)
precision, recall, thresholds = precision_recall_curve(np.array(Y_train),Y_pred_p)
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(fpr,tpr)#数据输入
plt.plot([0,1],[0,1],linestyle='--')#直线
plt.xlabel('False Postive Rate')#x坐标
plt.ylabel('True Positive Rate')#y坐标
plt.grid()#网格
plt.show()
plt.figure(figsize=(5,4),dpi=100)#作图
plt.plot(precision,recall)#数据输入
plt.plot([0,1],[1,0],linestyle='--')#直线
plt.xlabel('recall')#x坐标
plt.ylabel('precision')#y坐标
plt.grid()#网格
plt.show()
# Out:
# Done.
# confusion_matrix:
# [[510 115]
#  [ 32 582]]
# Done.
# cohen_kappa_score: 0.762975
